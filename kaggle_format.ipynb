# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/NNDL_Project
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NNDL_Project

# %%
df = pd.read_csv('probabilistic_superandsub_test_predictions.csv')
df.head()
# Out:
#    image  superclass_index  subclass_index
# 0  0.jpg                 1              46
# 1  1.jpg                 0              86
# 2  2.jpg                 2              29
# 3  3.jpg                 2              43
# 4  4.jpg                 1              49

# %%
df_super = df.rename(columns={'image': 'ID', 'superclass_index': 'Target'})
df_super = df_super.drop(['subclass_index'], axis=1)
df_super.head()
df_super.to_csv('superclass_results.csv', index=False)

# %%
df_sub = df.rename(columns={'image': 'ID', 'subclass_index': 'Target'})
df_sub = df_sub.drop(['superclass_index'], axis=1)
df_sub.head()
df_sub.to_csv('subclass_results.csv', index=False)
